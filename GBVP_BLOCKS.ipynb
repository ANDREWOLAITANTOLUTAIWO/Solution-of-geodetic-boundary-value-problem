# %%
import numpy as np
import math
import pandas as pd

# Access the datasets
datagrav = pd.read_csv('LAGOS_NEAR_POINTS_GRAV.csv')
datacont = pd.read_csv('LAGOS_NEAR_POINTS_CONTROLS.csv')

# Form vectors from fields in each dataset
blockid = datagrav['BLOCK_ID']
gravid = datagrav['GRAV_ID']
psi_g = datagrav['GRAV_DIST']
lamda = datagrav['GRAV_LON']
phi = datagrav['GRAV_LAT']
Sgrav = datagrav['GRAV_DIST']

blockid = datacont['BLOCK_ID']
contid = datacont['CONT_ID']
psi_c = datacont['CONT_DIST']

# %%
# Compute area of each block A
A = 2 * 60 * 30

# Compute 4*pi*gamma*R
gamma =  9.780;     # Normal gravity
R = 6371000         # Mean Earth radius
G = 4*np.pi*gamma*R

# How many gravity stations are in each bloock?
k_grav = datagrav.groupby('BLOCK_ID').count()

# Write it into an Excel file
k_grav.to_csv('LAGOS_GRAV_NUM.csv')

k_grav = k_grav['GRAV_DIST']

# How many control points are in each bloock?
k_cont = datacont.groupby('BLOCK_ID').count()

# %%
# Compute mean gravity anomaly in each block
grav_mean = datagrav.groupby('BLOCK_ID')['GRAV_ANOM'].mean()
# Write it into an Excel file
grav_mean.to_csv('GRAV_MEAN.csv')

# Initializing
S_grav = np.zeros(gravid.size)


for i in range(len('BLOCK_ID')): 
    # Compute Stoke's function S for each gravity station in each compartment
    S_grav = np.zeros(gravid.size)
    S_grav[i] = sum((1/(sin(0.5*psi_g)) - 6*sin(0.5*psi_g) - 5*cos(psi_g) - 3*cos(psi_g) * math.log(sin(0.5*psi_g) + (sin(0.5*psi_g))**2)))

    # Compute Ck for each block
    Ck = zeros(gravid.size)
    Ck = A * S_grav / G

# Compute N
    N[i] = Ck * grav_mean[k]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\sympy\core\cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 try:
# ---> 70     retval = cfunc(*args, **kwargs)
#      71 except TypeError as e:
#
# TypeError: unhashable type: 'Series'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\sympy\core\cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 try:
# ---> 70     retval = cfunc(*args, **kwargs)
#      71 except TypeError as e:
#
# TypeError: unhashable type: 'Series'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
a = [1, 2, 3, 4]
b = np.zeros(4)
for i in range(len(a)):
    b[i] = sum(a)
b
# Out:
# array([10., 10., 10., 10.])

# %%
grav_dist = zeros(320)
for i in range(len('BLOCK_ID')):
    grav_dist = datagrav.groupby('BLOCK_ID')['GRAV_DIST'].apply(lambda x: x[i])
grav_dist
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
for i in range(len('GRAV_ID')): 
    # Compute Stoke's function S for each gravity station in each compartment
    for k in range(k_grav[i]):
        print(psi_g[k])
# Out:
#   Cell In[97], line 6
#     psi_g
#          ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
psi_g
# Out:
# 0       0.021343
# 1       0.023568
# 2       0.026876
# 3       0.028675
# 4       0.016665
#           ...
# 1063    0.017596
# 1064    0.024303
# 1065    0.008219
# 1066    0.013229
# 1067    0.032740
# Name: GRAV_DIST, Length: 1068, dtype: float64
